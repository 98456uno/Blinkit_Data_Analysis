# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Blinkit_Dataset.csv.csv")
df
# Out:
#        order_id  customer_id              order_date  promised_delivery_time  \
# 0    1961864118     30065862  17-07-2024 08:34:01 AM  17-07-2024 08:52:01 AM
# 1    1961864118     30065862  17-07-2024 08:34:01 AM  17-07-2024 08:52:01 AM
# 2    8247327365     30065862  25-09-2024 11:15:52 AM  25-09-2024 11:28:52 AM
# 3    8247327365     30065862  25-09-2024 11:15:52 AM  25-09-2024 11:28:52 AM
# 4    1002526452     97475543  31-07-2023 11:19:05 PM  31-07-2023 11:29:05 PM
# ..          ...          ...                     ...                     ...
# 995  1375867721      4862761  15-07-2024 04:57:54 PM  15-07-2024 05:08:54 PM
# 996   277502363     88203688  28-12-2023 01:54:57 PM  28-12-2023 02:04:57 PM
# 997   277502363     88203688  28-12-2023 01:54:57 PM  28-12-2023 02:04:57 PM
# 998  8250036360     88203688  21-06-2024 02:01:28 PM  21-06-2024 02:20:28 PM
# 999  8250036360     88203688  21-06-2024 02:01:28 PM  21-06-2024 02:20:28 PM
#
#        actual_delivery_time   delivery_status  order_total payment_method  \
# 0    17-07-2024 08:47:01 AM           On Time      3197.07           Cash
# 1    17-07-2024 08:47:01 AM           On Time      3197.07           Cash
# 2    25-09-2024 11:42:52 AM  Slightly Delayed      2592.28           Card
# 3    25-09-2024 11:42:52 AM  Slightly Delayed      2592.28           Card
# 4    31-07-2023 11:33:05 PM           On Time      5001.82           Cash
# ..                      ...               ...          ...            ...
# 995  15-07-2024 05:05:54 PM           On Time      2244.24           Cash
# 996  28-12-2023 02:09:57 PM           On Time      2682.72           Card
# 997  28-12-2023 02:09:57 PM           On Time      2682.72           Card
# 998  21-06-2024 02:21:28 PM           On Time      1940.19         Wallet
# 999  21-06-2024 02:21:28 PM           On Time      1940.19         Wallet
#
#      delivery_partner_id  store_id  ... reasons_if_delayed        Date  \
# 0                  63230      4771  ...                NaN  17-07-2024
# 1                  63230      4771  ...                NaN  17-07-2024
# 2                  11031      4986  ...            Traffic  25-09-2024
# 3                  11031      4986  ...            Traffic  25-09-2024
# 4                  56579       852  ...            Traffic  31-07-2023
# ..                   ...       ...  ...                ...         ...
# 995                21511       548  ...                NaN  15-07-2024
# 996                18055      9608  ...            Traffic  28-12-2023
# 997                18055      9608  ...            Traffic  28-12-2023
# 998                65016      3376  ...            Traffic  21-06-2024
# 999                65016      3376  ...            Traffic  21-06-2024
#
#      Value_type    Value                                       Emoji   Star  \
# 0      Quantity     3.00     https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 1         Value  1551.09     https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 2      Quantity     3.00  https://i.postimg.cc/d02zccny/confused.png    ⭐⭐⭐
# 3         Value   580.38  https://i.postimg.cc/d02zccny/confused.png    ⭐⭐⭐
# 4      Quantity     2.00     https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# ..          ...      ...                                         ...    ...
# 995       Value   463.50     https://i.postimg.cc/15zP0XBY/angry.png      ⭐
# 996    Quantity     1.00  https://i.postimg.cc/d02zccny/confused.png    ⭐⭐⭐
# 997       Value   441.20  https://i.postimg.cc/d02zccny/confused.png    ⭐⭐⭐
# 998    Quantity     3.00      https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 999       Value  1202.76      https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
#
#                                                   Img  \
# 0          https://i.postimg.cc/FRMdmQjx/pet-food.png
# 1          https://i.postimg.cc/FRMdmQjx/pet-food.png
# 2    https://i.postimg.cc/1tnnLzNt/cleaning-tools.png
# 3    https://i.postimg.cc/1tnnLzNt/cleaning-tools.png
# 4          https://i.postimg.cc/W3x7FCP9/pharmacy.png
# ..                                                ...
# 995            https://i.postimg.cc/X7wFjX1B/food.png
# 996       https://i.postimg.cc/kXrKPWsd/softdrink.png
# 997       https://i.postimg.cc/kXrKPWsd/softdrink.png
# 998   https://i.postimg.cc/hvmm7GSw/personal-care.png
# 999   https://i.postimg.cc/hvmm7GSw/personal-care.png
#
#                       customer's address       area pincode
# 0     H.No. 330\nRana Path, Sagar 712033  Allahabad  911359
# 1     H.No. 330\nRana Path, Sagar 712033  Allahabad  911359
# 2     H.No. 330\nRana Path, Sagar 712033  Allahabad  911359
# 3     H.No. 330\nRana Path, Sagar 712033  Allahabad  911359
# 4    23, Nayar Path, Bihar Sharif-154625      Udupi  321865
# ..                                   ...        ...     ...
# 995       45, Sachar Ganj, Imphal 709402      Eluru  153679
# 996  31/15\nSundaram Road, Meerut-572312   Chittoor  743672
# 997  31/15\nSundaram Road, Meerut-572312   Chittoor  743672
# 998  31/15\nSundaram Road, Meerut-572312   Chittoor  743672
# 999  31/15\nSundaram Road, Meerut-572312   Chittoor  743672
#
# [1000 rows x 32 columns]

# %%
inventory_df = pd.read_csv("/content/blinkit_inventoryNew.csv")

# %%
merged_df = df.merge(inventory_df, on='product_id', how='left')
merged_df
# Out:
#          order_id  customer_id              order_date  \
# 0      1961864118     30065862  17-07-2024 08:34:01 AM
# 1      1961864118     30065862  17-07-2024 08:34:01 AM
# 2      1961864118     30065862  17-07-2024 08:34:01 AM
# 3      1961864118     30065862  17-07-2024 08:34:01 AM
# 4      1961864118     30065862  17-07-2024 08:34:01 AM
# ...           ...          ...                     ...
# 67909  8250036360     88203688  21-06-2024 02:01:28 PM
# 67910  8250036360     88203688  21-06-2024 02:01:28 PM
# 67911  8250036360     88203688  21-06-2024 02:01:28 PM
# 67912  8250036360     88203688  21-06-2024 02:01:28 PM
# 67913  8250036360     88203688  21-06-2024 02:01:28 PM
#
#        promised_delivery_time    actual_delivery_time delivery_status  \
# 0      17-07-2024 08:52:01 AM  17-07-2024 08:47:01 AM         On Time
# 1      17-07-2024 08:52:01 AM  17-07-2024 08:47:01 AM         On Time
# 2      17-07-2024 08:52:01 AM  17-07-2024 08:47:01 AM         On Time
# 3      17-07-2024 08:52:01 AM  17-07-2024 08:47:01 AM         On Time
# 4      17-07-2024 08:52:01 AM  17-07-2024 08:47:01 AM         On Time
# ...                       ...                     ...             ...
# 67909  21-06-2024 02:20:28 PM  21-06-2024 02:21:28 PM         On Time
# 67910  21-06-2024 02:20:28 PM  21-06-2024 02:21:28 PM         On Time
# 67911  21-06-2024 02:20:28 PM  21-06-2024 02:21:28 PM         On Time
# 67912  21-06-2024 02:20:28 PM  21-06-2024 02:21:28 PM         On Time
# 67913  21-06-2024 02:20:28 PM  21-06-2024 02:21:28 PM         On Time
#
#        order_total payment_method  delivery_partner_id  store_id  ...  \
# 0          3197.07           Cash                63230      4771  ...
# 1          3197.07           Cash                63230      4771  ...
# 2          3197.07           Cash                63230      4771  ...
# 3          3197.07           Cash                63230      4771  ...
# 4          3197.07           Cash                63230      4771  ...
# ...            ...            ...                  ...       ...  ...
# 67909      1940.19         Wallet                65016      3376  ...
# 67910      1940.19         Wallet                65016      3376  ...
# 67911      1940.19         Wallet                65016      3376  ...
# 67912      1940.19         Wallet                65016      3376  ...
# 67913      1940.19         Wallet                65016      3376  ...
#
#          Value                                    Emoji   Star  \
# 0         3.00  https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 1         3.00  https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 2         3.00  https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 3         3.00  https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 4         3.00  https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# ...        ...                                      ...    ...
# 67909  1202.76   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67910  1202.76   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67911  1202.76   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67912  1202.76   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67913  1202.76   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
#
#                                                    Img  \
# 0           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 1           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 2           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 3           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 4           https://i.postimg.cc/FRMdmQjx/pet-food.png
# ...                                                ...
# 67909  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67910  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67911  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67912  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67913  https://i.postimg.cc/hvmm7GSw/personal-care.png
#
#                         customer's address       area  pincode    date  \
# 0       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Mar-23
# 1       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Mar-23
# 2       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Mar-23
# 3       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Apr-23
# 4       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Apr-23
# ...                                    ...        ...      ...     ...
# 67909  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Oct-24
# 67910  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Oct-24
# 67911  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Oct-24
# 67912  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Nov-24
# 67913  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Nov-24
#
#       stock_received damaged_stock
# 0                  1             0
# 1                  2             0
# 2                  2             0
# 3                  1             0
# 4                  1             0
# ...              ...           ...
# 67909              3             0
# 67910              1             0
# 67911              1             0
# 67912              3             0
# 67913              3             0
#
# [67914 rows x 35 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67914 entries, 0 to 67913
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                67914 non-null  int64
#  1   customer_id             67914 non-null  int64
#  2   order_date              67914 non-null  object
#  3   promised_delivery_time  67914 non-null  object
#  4   actual_delivery_time    67914 non-null  object
#  5   delivery_status         67914 non-null  object
#  6   order_total             67914 non-null  float64
#  7   payment_method          67914 non-null  object
#  8   delivery_partner_id     67914 non-null  int64
#  9   store_id                67914 non-null  int64
#  10  customer_name           67914 non-null  object
#  11  customer_segment        67914 non-null  object
#  12  product_id              67914 non-null  int64
#  13  product_name            67914 non-null  object
#  14  category                67914 non-null  object
#  15  price                   67914 non-null  float64
#  16  rating                  67914 non-null  int64
#  17  feedback_text           67914 non-null  object
#  18  feedback_category       67914 non-null  object
#  19  sentiment               67914 non-null  object
#  20  delivery_time_minutes   67914 non-null  int64
#  21  distance_km             67914 non-null  float64
#  22  reasons_if_delayed      41540 non-null  object
#  23  Date                    67914 non-null  object
#  24  Value_type              67914 non-null  object
#  25  Value                   67914 non-null  float64
#  26  Emoji                   67914 non-null  object
#  27  Star                    67914 non-null  object
#  28  Img                     67914 non-null  object
#  29  customer's address      67914 non-null  object
#  30  area                    67914 non-null  object
#  31  pincode                 67914 non-null  int64
#  32  date                    67914 non-null  object
#  33  stock_received          67914 non-null  int64
#  34  damaged_stock           67914 non-null  int64
# dtypes: float64(4), int64(10), object(21)
# memory usage: 18.1+ MB

# %%
merged_df.describe()
# Out:
#            order_id   customer_id   order_total  delivery_partner_id  \
# count  6.791400e+04  6.791400e+04  67914.000000         67914.000000
# mean   5.024854e+09  4.973648e+07   2215.050042         51822.826280
# std    2.791413e+09  3.019186e+07   1326.243295         28266.656678
# min    3.261302e+07  2.438380e+05     22.140000           102.000000
# 25%    2.558681e+09  2.159748e+07   1064.760000         28575.000000
# 50%    5.127173e+09  5.076075e+07   2118.040000         52847.000000
# 75%    7.154957e+09  7.786245e+07   3223.070000         76160.000000
# max    9.997122e+09  9.989390e+07   5804.230000         99898.000000
#
#            store_id     product_id         price        rating  \
# count  67914.000000   67914.000000  67914.000000  67914.000000
# mean    4912.751097  519918.110080    491.649736      3.410342
# std     2855.753387  284390.097974    299.863274      1.132437
# min       12.000000    6405.000000     12.320000      1.000000
# 25%     2463.000000  284460.000000    217.400000      3.000000
# 50%     4923.000000  555121.000000    475.040000      4.000000
# 75%     7297.000000  757274.000000    787.400000      4.000000
# max     9981.000000  993331.000000    995.980000      5.000000
#
#        delivery_time_minutes   distance_km         Value        pincode  \
# count           67914.000000  67914.000000  67914.000000   67914.000000
# mean                4.173838      2.658413    482.086027  502072.613099
# std                 7.726200      1.296222    719.524965  285945.876540
# min                -5.000000      0.530000      1.000000    9792.000000
# 25%                -1.000000      1.540000      2.000000  271335.000000
# 50%                 2.000000      2.540000      8.125000  499186.000000
# 75%                 8.000000      3.820000    785.670000  766033.000000
# max                30.000000      4.990000   2987.940000  999631.000000
#
#        stock_received  damaged_stock
# count    67914.000000   67914.000000
# mean         1.588362       0.060164
# std          0.794273       0.259469
# min          1.000000       0.000000
# 25%          1.000000       0.000000
# 50%          1.000000       0.000000
# 75%          2.000000       0.000000
# max          4.000000       6.000000

# %%
merged_df.isnull().sum()
# Out:
# order_id                      0
# customer_id                   0
# order_date                    0
# promised_delivery_time        0
# actual_delivery_time          0
# delivery_status               0
# order_total                   0
# payment_method                0
# delivery_partner_id           0
# store_id                      0
# customer_name                 0
# customer_segment              0
# product_id                    0
# product_name                  0
# category                      0
# price                         0
# rating                        0
# feedback_text                 0
# feedback_category             0
# sentiment                     0
# delivery_time_minutes         0
# distance_km                   0
# reasons_if_delayed        26374
# Date                          0
# Value_type                    0
# Value                         0
# Emoji                         0
# Star                          0
# Img                           0
# customer's address            0
# area                          0
# pincode                       0
# date                          0
# stock_received                0
# damaged_stock                 0
# dtype: int64

# %%
merged_df.dropna
merged_df.shape
# Out:
# (67914, 35)

# %%
merged_df.drop(columns=['reasons_if_delayed'], inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# customer_name             0
# customer_segment          0
# product_id                0
# product_name              0
# category                  0
# price                     0
# rating                    0
# feedback_text             0
# feedback_category         0
# sentiment                 0
# delivery_time_minutes     0
# distance_km               0
# Date                      0
# Value_type                0
# Value                     0
# Emoji                     0
# Star                      0
# Img                       0
# customer's address        0
# area                      0
# pincode                   0
# date                      0
# stock_received            0
# damaged_stock             0
# dtype: int64

# %%
merged_df['order_id'].duplicated().sum()
# Out:
# np.int64(67414)

# %%
merged_df_unique_orders = df.drop_duplicates(subset='order_id', keep='first')

# %%
merged_df.shape
# Out:
# (67914, 34)

# %%
merged_df.drop_duplicates(inplace=True)

# %%
merged_df.shape
# Out:
# (40256, 34)

# %%
merged_df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
merged_df['promised_delivery_time'] = pd.to_datetime(df['promised_delivery_time'], errors='coerce')
merged_df['actual_delivery_time'] = pd.to_datetime(df['actual_delivery_time'], errors='coerce')

# %%
def categorize_speed(minutes):
    if minutes <= 10:
        return 'Fast'
    elif minutes <= 20:
        return 'Moderate'
    else:
        return 'Slow'

merged_df['delivery_speed'] = merged_df['delivery_time_minutes'].apply(categorize_speed)

# %%
merged_df
# Out:
#          order_id  customer_id          order_date promised_delivery_time  \
# 0      1961864118     30065862 2024-07-17 08:34:01    2024-07-17 08:52:01
# 1      1961864118     30065862 2024-07-17 08:34:01    2024-07-17 08:52:01
# 3      1961864118     30065862 2024-09-25 11:15:52    2024-09-25 11:28:52
# 5      1961864118     30065862 2023-07-31 23:19:05    2023-07-31 23:29:05
# 7      1961864118     30065862 2024-03-07 08:59:56    2024-03-07 09:17:56
# ...           ...          ...                 ...                    ...
# 67905  8250036360     88203688                 NaT                    NaT
# 67906  8250036360     88203688                 NaT                    NaT
# 67908  8250036360     88203688                 NaT                    NaT
# 67910  8250036360     88203688                 NaT                    NaT
# 67912  8250036360     88203688                 NaT                    NaT
#
#       actual_delivery_time delivery_status  order_total payment_method  \
# 0      2024-07-17 08:47:01         On Time      3197.07           Cash
# 1      2024-07-17 08:47:01         On Time      3197.07           Cash
# 3      2024-09-25 11:42:52         On Time      3197.07           Cash
# 5      2023-07-31 23:33:05         On Time      3197.07           Cash
# 7      2024-03-07 09:21:56         On Time      3197.07           Cash
# ...                    ...             ...          ...            ...
# 67905                  NaT         On Time      1940.19         Wallet
# 67906                  NaT         On Time      1940.19         Wallet
# 67908                  NaT         On Time      1940.19         Wallet
# 67910                  NaT         On Time      1940.19         Wallet
# 67912                  NaT         On Time      1940.19         Wallet
#
#        delivery_partner_id  store_id  ...  \
# 0                    63230      4771  ...
# 1                    63230      4771  ...
# 3                    63230      4771  ...
# 5                    63230      4771  ...
# 7                    63230      4771  ...
# ...                    ...       ...  ...
# 67905                65016      3376  ...
# 67906                65016      3376  ...
# 67908                65016      3376  ...
# 67910                65016      3376  ...
# 67912                65016      3376  ...
#
#                                          Emoji   Star  \
# 0      https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 1      https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 3      https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 5      https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# 7      https://i.postimg.cc/X7XSGhNR/smile.png   ⭐⭐⭐⭐
# ...                                        ...    ...
# 67905   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67906   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67908   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67910   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
# 67912   https://i.postimg.cc/XYyRxCCx/star.png  ⭐⭐⭐⭐⭐
#
#                                                    Img  \
# 0           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 1           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 3           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 5           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 7           https://i.postimg.cc/FRMdmQjx/pet-food.png
# ...                                                ...
# 67905  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67906  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67908  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67910  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67912  https://i.postimg.cc/hvmm7GSw/personal-care.png
#
#                         customer's address       area  pincode    date  \
# 0       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Mar-23
# 1       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Mar-23
# 3       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Apr-23
# 5       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  Apr-23
# 7       H.No. 330\nRana Path, Sagar 712033  Allahabad   911359  May-23
# ...                                    ...        ...      ...     ...
# 67905  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Aug-24
# 67906  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Sep-24
# 67908  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Oct-24
# 67910  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Oct-24
# 67912  31/15\nSundaram Road, Meerut-572312   Chittoor   743672  Nov-24
#
#       stock_received damaged_stock delivery_speed
# 0                  1             0           Fast
# 1                  2             0           Fast
# 3                  1             0           Fast
# 5                  2             0           Fast
# 7                  1             0           Fast
# ...              ...           ...            ...
# 67905              4             0           Fast
# 67906              3             0           Fast
# 67908              3             0           Fast
# 67910              1             0           Fast
# 67912              3             0           Fast
#
# [40256 rows x 35 columns]

# %%
def rate_bucket(r):
    if r >= 4:
        return 'High'
    elif r >= 2.5:
        return 'Medium'
    else:
        return 'Low'

merged_df['rating_category'] = merged_df['rating'].apply(rate_bucket)

# %%
merged_df
# Out:
#          order_id  customer_id          order_date promised_delivery_time  \
# 0      1961864118     30065862 2024-07-17 08:34:01    2024-07-17 08:52:01
# 1      1961864118     30065862 2024-07-17 08:34:01    2024-07-17 08:52:01
# 3      1961864118     30065862 2024-09-25 11:15:52    2024-09-25 11:28:52
# 5      1961864118     30065862 2023-07-31 23:19:05    2023-07-31 23:29:05
# 7      1961864118     30065862 2024-03-07 08:59:56    2024-03-07 09:17:56
# ...           ...          ...                 ...                    ...
# 67905  8250036360     88203688                 NaT                    NaT
# 67906  8250036360     88203688                 NaT                    NaT
# 67908  8250036360     88203688                 NaT                    NaT
# 67910  8250036360     88203688                 NaT                    NaT
# 67912  8250036360     88203688                 NaT                    NaT
#
#       actual_delivery_time delivery_status  order_total payment_method  \
# 0      2024-07-17 08:47:01         On Time      3197.07           Cash
# 1      2024-07-17 08:47:01         On Time      3197.07           Cash
# 3      2024-09-25 11:42:52         On Time      3197.07           Cash
# 5      2023-07-31 23:33:05         On Time      3197.07           Cash
# 7      2024-03-07 09:21:56         On Time      3197.07           Cash
# ...                    ...             ...          ...            ...
# 67905                  NaT         On Time      1940.19         Wallet
# 67906                  NaT         On Time      1940.19         Wallet
# 67908                  NaT         On Time      1940.19         Wallet
# 67910                  NaT         On Time      1940.19         Wallet
# 67912                  NaT         On Time      1940.19         Wallet
#
#        delivery_partner_id  store_id  ...   Star  \
# 0                    63230      4771  ...   ⭐⭐⭐⭐
# 1                    63230      4771  ...   ⭐⭐⭐⭐
# 3                    63230      4771  ...   ⭐⭐⭐⭐
# 5                    63230      4771  ...   ⭐⭐⭐⭐
# 7                    63230      4771  ...   ⭐⭐⭐⭐
# ...                    ...       ...  ...    ...
# 67905                65016      3376  ...  ⭐⭐⭐⭐⭐
# 67906                65016      3376  ...  ⭐⭐⭐⭐⭐
# 67908                65016      3376  ...  ⭐⭐⭐⭐⭐
# 67910                65016      3376  ...  ⭐⭐⭐⭐⭐
# 67912                65016      3376  ...  ⭐⭐⭐⭐⭐
#
#                                                    Img  \
# 0           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 1           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 3           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 5           https://i.postimg.cc/FRMdmQjx/pet-food.png
# 7           https://i.postimg.cc/FRMdmQjx/pet-food.png
# ...                                                ...
# 67905  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67906  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67908  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67910  https://i.postimg.cc/hvmm7GSw/personal-care.png
# 67912  https://i.postimg.cc/hvmm7GSw/personal-care.png
#
#                         customer's address       area pincode    date  \
# 0       H.No. 330\nRana Path, Sagar 712033  Allahabad  911359  Mar-23
# 1       H.No. 330\nRana Path, Sagar 712033  Allahabad  911359  Mar-23
# 3       H.No. 330\nRana Path, Sagar 712033  Allahabad  911359  Apr-23
# 5       H.No. 330\nRana Path, Sagar 712033  Allahabad  911359  Apr-23
# 7       H.No. 330\nRana Path, Sagar 712033  Allahabad  911359  May-23
# ...                                    ...        ...     ...     ...
# 67905  31/15\nSundaram Road, Meerut-572312   Chittoor  743672  Aug-24
# 67906  31/15\nSundaram Road, Meerut-572312   Chittoor  743672  Sep-24
# 67908  31/15\nSundaram Road, Meerut-572312   Chittoor  743672  Oct-24
# 67910  31/15\nSundaram Road, Meerut-572312   Chittoor  743672  Oct-24
# 67912  31/15\nSundaram Road, Meerut-572312   Chittoor  743672  Nov-24
#
#        stock_received damaged_stock delivery_speed rating_category
# 0                   1             0           Fast            High
# 1                   2             0           Fast            High
# 3                   1             0           Fast            High
# 5                   2             0           Fast            High
# 7                   1             0           Fast            High
# ...               ...           ...            ...             ...
# 67905               4             0           Fast            High
# 67906               3             0           Fast            High
# 67908               3             0           Fast            High
# 67910               1             0           Fast            High
# 67912               3             0           Fast            High
#
# [40256 rows x 36 columns]

# %%
merged_df['Available_Stock'] = merged_df['stock_received'] - merged_df['damaged_stock']
merged_df.dropna()
df.shape
# Out:
# (1000, 32)

# %%
print(merged_df.columns)
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'promised_delivery_time',
#        'actual_delivery_time', 'delivery_status', 'order_total',
#        'payment_method', 'delivery_partner_id', 'store_id', 'customer_name',
#        'customer_segment', 'product_id', 'product_name', 'category', 'price',
#        'rating', 'feedback_text', 'feedback_category', 'sentiment',
#        'delivery_time_minutes', 'distance_km', 'Date', 'Value_type', 'Value',
#        'Emoji', 'Star', 'Img', 'customer's address', 'area', 'pincode', 'date',
#        'stock_received', 'damaged_stock', 'delivery_speed', 'rating_category',
#        'Available_Stock'],
#       dtype='object')

# %%
merged_df.drop(columns=['Img','Emoji'], inplace=True)

# %%
print(merged_df.columns)
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'promised_delivery_time',
#        'actual_delivery_time', 'delivery_status', 'order_total',
#        'payment_method', 'delivery_partner_id', 'store_id', 'customer_name',
#        'customer_segment', 'product_id', 'product_name', 'category', 'price',
#        'rating', 'feedback_text', 'feedback_category', 'sentiment',
#        'delivery_time_minutes', 'distance_km', 'Date', 'Value_type', 'Value',
#        'Star', 'customer's address', 'area', 'pincode', 'date',
#        'stock_received', 'damaged_stock', 'delivery_speed', 'rating_category',
#        'Available_Stock'],
#       dtype='object')

# %% [markdown]
# **Order Level Insights**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print("Most Frequently Ordered Product Categories:")
category_counts = merged_df['category'].value_counts()
print(category_counts)

blinkit_palette_10 = [ '#FFCD00','#00A862', '#000000','#A8A8A8',  '#505050',  '#FFC300', '#009E73',  '#343434',  '#E6B800', '#007F5F']


plt.figure(figsize=(10,6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette=blinkit_palette_10,edgecolor='black')
plt.title('Most Frequently Ordered Product Categories')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Most Frequently Ordered Product Categories:
# category
# Dairy & Breakfast        5448
# Pharmacy                 4952
# Pet Care                 4234
# Fruits & Vegetables      3978
# Household Care           3970
# Snacks & Munchies        3626
# Grocery & Staples        3540
# Cold Drinks & Juices     2978
# Personal Care            2870
# Instant & Frozen Food    2660
# Baby Care                2000
# Name: count, dtype: int64

# %%
print("Total Revenue per Product Category:")
Total_Revenue=merged_df.groupby('category')
Total_Revenue = merged_df.groupby('category')['order_total'].sum().sort_values(ascending=False) / 1e5
print(Total_Revenue)


plt.figure(figsize=(10,6))
sns.barplot(y=Total_Revenue.index, x=Total_Revenue.values, palette=blinkit_palette_10,edgecolor='black')
plt.title('Total Revenue per Product Category')
plt.xlabel('Revenue (₹ Lakh)')
plt.ylabel('Product Category')
plt.tight_layout()
plt.show()
# Out:
# Total Revenue per Product Category:
# category
# Dairy & Breakfast        114.626887
# Pharmacy                 114.491032
# Pet Care                 105.254123
# Grocery & Staples         89.450394
# Household Care            85.736291
# Fruits & Vegetables       76.881863
# Snacks & Munchies         73.472337
# Cold Drinks & Juices      64.308810
# Instant & Frozen Food     63.242555
# Personal Care             58.201194
# Baby Care                 45.223799
# Name: order_total, dtype: float64
# /tmp/ipython-input-291-3954676878.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=Total_Revenue.index, x=Total_Revenue.values, palette=blinkit_palette_10,edgecolor='black')
# /tmp/ipython-input-291-3954676878.py:8: UserWarning:
# The palette list has fewer values (10) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(y=Total_Revenue.index, x=Total_Revenue.values, palette=blinkit_palette_10,edgecolor='black')

# %%
print("Average order value per customer segment")
Average_Order_Value = merged_df.groupby("customer_segment")
Average_Order_Value = Average_Order_Value["order_total"].mean().sort_values(ascending=False)
print(Average_Order_Value)

plt.figure(figsize=(13,4))
sns.barplot(x=Average_Order_Value.values, y=Average_Order_Value.index, palette=blinkit_palette_10,edgecolor='black')
plt.title('Average Order Value per Customer Segment')
plt.xlabel('Average Order Value (₹)')
plt.ylabel('Customer Segment')

for i, v in enumerate(Average_Order_Value.values):
    plt.text(v + 10, i, f'{v:.2f}', va='center', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# Average order value per customer segment
# customer_segment
# New         2436.095977
# Regular     2298.743426
# Premium     2236.611724
# Inactive    1905.042036
# Name: order_total, dtype: float64
# /tmp/ipython-input-292-1486929658.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Average_Order_Value.values, y=Average_Order_Value.index, palette=blinkit_palette_10,edgecolor='black')
# /tmp/ipython-input-292-1486929658.py:7: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.barplot(x=Average_Order_Value.values, y=Average_Order_Value.index, palette=blinkit_palette_10,edgecolor='black')

# %%
print("payment meathod usage frequency")
payment_method_counts = merged_df['payment_method'].value_counts()
print("Payment methods usage frequency")
print(payment_method_counts)

plt.figure(figsize=(7,7))
plt.pie( payment_method_counts.values, labels=payment_method_counts.index, autopct='%1.1f%%',startangle=90,colors=sns.color_palette(blinkit_palette_10),wedgeprops={'width': 0.4},textprops={'color':'red'})
plt.title('Payment Method Usage Frequency')
plt.tight_layout()
plt.show()
# Out:
# payment meathod usage frequency
# Payment methods usage frequency
# payment_method
# Wallet    10944
# Card      10580
# Cash       9482
# UPI        9250
# Name: count, dtype: int64

# %% [markdown]
# **DELIVERY** & **LOGISTICS**

# %%
print("Average Delivery Time per Category:")
Delivery_time_category = merged_df.groupby('category')
Delivery_time_category=Delivery_time_category['delivery_time_minutes'].mean().sort_values()
print(Delivery_time_category)

plt.figure(figsize=(10,6))
sns.barplot(x=Delivery_time_category.values, y=Delivery_time_category.index, palette=blinkit_palette_10,edgecolor='black')
plt.title('Average Delivery Time per Category')
plt.xlabel('Average Delivery Time (minutes)')
plt.ylabel('Product Category')


plt.tight_layout()
plt.show()
# Out:
# Average Delivery Time per Category:
# category
# Dairy & Breakfast        3.329295
# Cold Drinks & Juices     3.407656
# Pharmacy                 3.582391
# Fruits & Vegetables      3.665661
# Pet Care                 3.748229
# Household Care           4.304282
# Personal Care            4.367247
# Instant & Frozen Food    4.635338
# Snacks & Munchies        4.836735
# Grocery & Staples        5.003390
# Baby Care                7.418000
# Name: delivery_time_minutes, dtype: float64
# /tmp/ipython-input-294-166094857.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Delivery_time_category.values, y=Delivery_time_category.index, palette=blinkit_palette_10,edgecolor='black')
# /tmp/ipython-input-294-166094857.py:7: UserWarning:
# The palette list has fewer values (10) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=Delivery_time_category.values, y=Delivery_time_category.index, palette=blinkit_palette_10,edgecolor='black')

# %%
print("Delivery Status Distribution (%):")
delivery_percentage = merged_df['delivery_status'].value_counts(normalize=True) * 100
print(delivery_percentage)

import matplotlib.pyplot as plt

delivery_percentage = merged_df['delivery_status'].value_counts(normalize=True) * 100

plt.figure(figsize=(7,7))
plt.pie(delivery_percentage.values,labels=delivery_percentage.index,autopct='%1.1f%%',startangle=90,colors=sns.color_palette(blinkit_palette_10),wedgeprops={'width': 0.4},textprops={'color': 'Red'})
plt.title('Delivery Status Distribution (%)')
plt.tight_layout()
plt.show()
# Out:
# Delivery Status Distribution (%):
# delivery_status
# On Time                  71.557035
# Slightly Delayed         20.593203
# Significantly Delayed     7.849762
# Name: proportion, dtype: float64

# %%
merged_df['delivery_delay_minutes'] = (pd.to_datetime(merged_df['actual_delivery_time']) - pd.to_datetime(merged_df['promised_delivery_time'])).dt.total_seconds() / 60
print("Top 4 Areas with Highest Average Delivery Delay (in minutes):")
delay_by_area=merged_df.groupby('area')['delivery_delay_minutes'].mean().dropna().sort_values(ascending=False)
print(delay_by_area.head(4))

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=delay_by_area.values, y=delay_by_area.index, palette=blinkit_palette_10,edgecolor='black')
plt.title('Top  Areas with Highest Average Delivery Delay (in Minutes)')
plt.xlabel('Average Delay (minutes)')
plt.ylabel('Area')

plt.tight_layout()
plt.show()
# Out:
# Top 4 Areas with Highest Average Delivery Delay (in minutes):
# area
# Alappuzha    5.147410
# Aligarh      3.521739
# Allahabad    2.869048
# Udupi        1.395349
# Name: delivery_delay_minutes, dtype: float64

# %%
print("Average Distance Covered per Delivery Partner:")

avg_distance = merged_df.groupby('delivery_partner_id')['distance_km'].mean().sort_values(ascending=False).head(10)
print(avg_distance)

plt.figure(figsize=(12,6))
sns.lineplot(x=avg_distance.index, y=avg_distance.values, marker='o', linewidth=2, color='yellow')
plt.title('Top 10 Delivery Partners by Average Distance Covered')
plt.xlabel('Delivery Partner ID')
plt.ylabel('Average Distance (km)')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Average Distance Covered per Delivery Partner:
# delivery_partner_id
# 59454    4.99
# 40500    4.98
# 35150    4.97
# 19224    4.93
# 37995    4.92
# 50582    4.91
# 89407    4.91
# 97547    4.90
# 56968    4.89
# 11104    4.88
# Name: distance_km, dtype: float64

# %% [markdown]
# **CUSTOMER BEHAVIOUR & SEGMENTATION**

# %%
print("Top 10 Customers by Total Order Value:")
customer = merged_df.groupby('customer_id')['order_total'].sum().sort_values(ascending=False).head(10)
print(customer)


plt.figure(figsize=(10, 6))
sns.barplot(
    x=customer.index,
    y=customer.values,
    palette=blinkit_palette_10,
    edgecolor='black'
)

plt.title('Top 10 Customers by Total Order Value', fontsize=14)
plt.xlabel('Customer_ID', fontsize=12)
plt.ylabel('Total Order Value', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Customers by Total Order Value:
# customer_id
# 69863493    1148184.18
# 8791577     1112421.52
# 88324928    1051602.66
# 85519349     944701.70
# 67092149     918611.40
# 44410149     904803.10
# 41640262     879962.46
# 82594354     852714.58
# 57081917     828566.20
# 90346920     798387.22
# Name: order_total, dtype: float64
# /tmp/ipython-input-298-1051521144.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
repeat_counts = merged_df['customer_id'].value_counts()
print("Number of Repeat Customers:")
print((repeat_counts > 1).sum())
# Out:
# Number of Repeat Customers:
# 290

# %%
import matplotlib.pyplot as plt

avg_rating_segment = merged_df.groupby('customer_segment')['rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,8))
plt.pie(
    avg_rating_segment.values,
    labels=avg_rating_segment.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=sns.color_palette(blinkit_palette_10),
    textprops={'color': 'Red'}
)
plt.title('Average Rating by Customer Segment (Proportional View)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **PRODUCT LEVEL INSIGHTS**

# %%
print(" Top 10 Most Ordered Products:")
top_products = merged_df['product_name'].value_counts().head(10)
print(top_products)

plt.figure(figsize=(10,6))
sns.barplot(x=top_products.values, y=top_products.index, palette=blinkit_palette_10,edgecolor='black')
plt.title('Top 10 Most Ordered Products')
plt.xlabel('Number of Orders')
plt.ylabel('Product Name')

plt.tight_layout()
plt.show()
# Out:
#  Top 10 Most Ordered Products:
# product_name
# Cough Syrup       2142
# Pet Treats        2072
# Vitamins          1642
# Bread             1624
# Toilet Cleaner    1540
# Dish Soap         1420
# Eggs              1374
# Potatoes          1358
# Biscuits          1356
# Frozen Pizza      1258
# Name: count, dtype: int64

# %%
top_products = merged_df.groupby('product_name').agg({'rating': 'mean', 'price': 'mean'}).sort_values(by='rating', ascending=False).head(10)
print("Product-wise Average Rating and Price:")
print(top_products)
colors = sns.color_palette(blinkit_palette_10)

plt.figure(figsize=(10,6))
for (product, row), color in zip(top_products.iterrows(), colors):
    plt.scatter(row['price'], row['rating'], color=color, s=100, label=product)

plt.title('Top 10 Products by Rating: Rating vs Price')
plt.xlabel('Average Price (₹)')
plt.ylabel('Average Rating')
plt.grid(True, linestyle='--', alpha=0.5)

plt.legend(title='Product Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Product-wise Average Rating and Price:
#                  rating       price
# product_name
# Milk           5.000000  598.830000
# Salt           4.593103  440.610345
# Baby Food      4.301205  770.542922
# Chips          4.020942  315.333613
# Popcorn        4.002387  287.156062
# Lemonade       4.000000  332.840000
# Onions         3.981352  554.445688
# Pain Reliever  3.926370  506.141712
# Biscuits       3.823009  526.638024
# Butter         3.814815  785.897870

# %%
import matplotlib.pyplot as plt

avg_price_by_category = merged_df.groupby('category')['price'].mean().sort_values(ascending=False)
print(avg_price_by_category)

plt.figure(figsize=(10,6))
plt.plot(avg_price_by_category.index, avg_price_by_category.values, marker='o', linestyle='-', color='#00A862')

plt.title('Average Price by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Average Price (₹)')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# category
# Baby Care                611.217510
# Cold Drinks & Juices     608.283801
# Pharmacy                 603.268530
# Personal Care            540.242348
# Fruits & Vegetables      515.447994
# Dairy & Breakfast        509.756869
# Snacks & Munchies        480.591616
# Pet Care                 467.413080
# Grocery & Staples        389.255011
# Instant & Frozen Food    373.796526
# Household Care           344.957300
# Name: price, dtype: float64

# %% [markdown]
# **AREA & GEOGRAPHIC INSIGHTS**

# %%
print("Top 10 Areas by Order Count:")
top_areas_order_count=merged_df['area'].value_counts().head(10)
print(top_areas_order_count)

plt.figure(figsize=(10,6))
sns.barplot(x=top_areas_order_count.index, y=top_areas_order_count.values, palette=blinkit_palette_10,edgecolor='black')

plt.title('Top 10 Areas by Order Count')
plt.xlabel('Area')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Areas by Order Count:
# area
# Ichalkaranji     1148
# Nizamabad         872
# Alappuzha         684
# Orai              548
# Visakhapatnam     542
# Ongole            508
# Nellore           500
# Karaikudi         496
# Kakinada          496
# Nandyal           492
# Name: count, dtype: int64
# /tmp/ipython-input-304-694432700.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_areas_order_count.index, y=top_areas_order_count.values, palette=blinkit_palette_10,edgecolor='black')

# %%
top_rated_areas = merged_df.groupby('area')['rating'].mean().sort_values(ascending=False).head(20)
print("Top 20 Areas by Average Rating:")
print(top_rated_areas)

plt.figure(figsize=(10,6))
plt.plot(top_rated_areas.values, top_rated_areas.index, marker='o', linestyle='-', color='#00A862')

plt.title('Top 10 Areas by Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Area')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Top 20 Areas by Average Rating:
# area
# Ahmedabad      5.000000
# Gandhidham     5.000000
# Kota           5.000000
# Shimla         5.000000
# Pune           5.000000
# Morbi          5.000000
# Jalna          5.000000
# Yamunanagar    4.689922
# Pudukkottai    4.614286
# Saharanpur     4.511905
# Panchkula      4.494118
# Korba          4.488372
# Ludhiana       4.475610
# Hindupur       4.383333
# Nandyal        4.345528
# Deoghar        4.302326
# Ghaziabad      4.271028
# Nagaon         4.269939
# Rajahmundry    4.239264
# Pondicherry    4.223214
# Name: rating, dtype: float64

# %%
merged_df['order_hour'] = pd.to_datetime(merged_df['order_date']).dt.hour
print("Order Count by Hour of the Day:")
hourly_orders = merged_df['order_hour'].value_counts().sort_index()
print("Order Count by Hour of the Day:")
print(hourly_orders)

plt.figure(figsize=(10,6))
plt.plot(hourly_orders.index, hourly_orders.values, marker='o', linestyle='-', color='#00A862')

plt.title('Order Count by Hour of the Day')
plt.xlabel('Hour of Day (0-23)')
plt.ylabel('Number of Orders')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Order Count by Hour of the Day:
# Order Count by Hour of the Day:
# order_hour
# 0.0     23
# 1.0     40
# 2.0     22
# 3.0     20
# 4.0     15
# 5.0     27
# 6.0     21
# 7.0     40
# 8.0     29
# 9.0     24
# 10.0    27
# 11.0    15
# 12.0    22
# 13.0    27
# 14.0    18
# 15.0    31
# 16.0    22
# 17.0    13
# 18.0    24
# 19.0    43
# 20.0    34
# 21.0    13
# 22.0    27
# 23.0    20
# Name: count, dtype: int64

# %%
merged_df['order_day'] = pd.to_datetime(merged_df['order_date']).dt.day_name()
print("Order Count by Day of the Week:")
order_day = merged_df['order_day'].value_counts()
print(order_day)

plt.figure(figsize=(10,6))
plt.plot(order_day.index, order_day.values, marker='o', linestyle='-', color='#FFCD00')

plt.title('Order Count by Day of the Week')
plt.xlabel('Day')
plt.ylabel('Number of Orders')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Order Count by Day of the Week:
# order_day
# Wednesday    97
# Sunday       93
# Friday       90
# Saturday     90
# Thursday     84
# Tuesday      74
# Monday       69
# Name: count, dtype: int64

# %% [markdown]
# *FEEDBACK & SENTIMENT ANALYSIS*

# %%
print("Sentiment Distribution of Customer Feedback:")
sentiment_counts = merged_df['sentiment'].value_counts()
print("Sentiment Distribution of Customer Feedback:")
print(sentiment_counts)

colors = ['#00A862', '#FFCD00', '#000000']

plt.figure(figsize=(6,6))
plt.pie(sentiment_counts.values, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=colors,textprops={"color":"red"})

plt.title('Sentiment Distribution of Customer Feedback')
plt.tight_layout()
plt.show()
# Out:
# Sentiment Distribution of Customer Feedback:
# Sentiment Distribution of Customer Feedback:
# sentiment
# Neutral     14962
# Positive    12712
# Negative    12582
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sentiment_rating = merged_df.groupby('sentiment')['rating'].mean()
print("Average Rating per Sentiment Category:")
print(sentiment_rating)

plt.figure(figsize=(8,5))
sns.barplot(x=sentiment_rating.index, y=sentiment_rating.values, palette=blinkit_palette_10,edgecolor='black')


plt.title('Average Rating per Sentiment Category')
plt.xlabel('Sentiment')
plt.ylabel('Average Rating')
plt.ylim(0, 5.5)
plt.grid(True, axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# Average Rating per Sentiment Category:
# sentiment
# Negative    2.113654
# Neutral     3.567304
# Positive    4.500157
# Name: rating, dtype: float64
# /tmp/ipython-input-309-112841256.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_rating.index, y=sentiment_rating.values, palette=blinkit_palette_10,edgecolor='black')
# /tmp/ipython-input-309-112841256.py:10: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.barplot(x=sentiment_rating.index, y=sentiment_rating.values, palette=blinkit_palette_10,edgecolor='black')

# %%
print("Top Categories Receiving Negative Sentiment:")
print("Unique Sentiment Values:")
print(df['sentiment'].unique())

negative_category_counts=merged_df[merged_df['sentiment'] == 'Negative']['category'].value_counts().head(5)

plt.figure(figsize=(6,6))
plt.pie(negative_category_counts.values, labels=negative_category_counts.index,
        autopct='%1.1f%%', colors=sns.color_palette(blinkit_palette_10, n_colors=5), startangle=140,textprops={'color':'red'})
plt.title('Negative Sentiment Share by Category')
plt.tight_layout()
plt.show()
# Out:
# Top Categories Receiving Negative Sentiment:
# Unique Sentiment Values:
# ['Neutral' 'Negative' 'Positive']

# %%
print("Correlation Matrix for Numerical Columns:")
corr_matrix=(merged_df[['price', 'rating', 'order_total', 'delivery_time_minutes', 'distance_km']].corr())
print(corr_matrix)


plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap=blinkit_palette_10, fmt=".2f", linewidths=0.5)

plt.title('Correlation Matrix: Price, Rating, Delivery Time, etc.')
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix for Numerical Columns:
#                           price    rating  order_total  delivery_time_minutes  \
# price                  1.000000 -0.041926    -0.050102               0.011989
# rating                -0.041926  1.000000     0.040894              -0.023641
# order_total           -0.050102  0.040894     1.000000               0.004707
# delivery_time_minutes  0.011989 -0.023641     0.004707               1.000000
# distance_km            0.062233  0.011728    -0.011734              -0.018079
#
#                        distance_km
# price                     0.062233
# rating                    0.011728
# order_total              -0.011734
# delivery_time_minutes    -0.018079
# distance_km               1.000000

# %%
print("Covariance Between Price and Rating:")
corr_matrix=(merged_df[['price', 'rating']].cov())
print(corr_matrix)
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap=blinkit_palette_10, linewidths=0.5, linecolor='white')

plt.title('Correlation Heatmap of Numerical Features')
plt.tight_layout()
plt.show()
# Out:
# Covariance Between Price and Rating:
#                price     rating
# price   90087.511157 -14.294577
# rating    -14.294577   1.290371

# %%
merged_df['damage_rate'] = (merged_df['damaged_stock'] / merged_df['stock_received']).round(2)

plt.figure(figsize=(9,6))
sns.histplot(data=merged_df, x='damage_rate', bins=20, color='#FFCD00', edgecolor='black')

plt.title('Distribution of Damage Rate')
plt.xlabel('Damage Rate')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
print("Top 10 Products with Highest Damage Rate")
top_damaged_products = merged_df.groupby('product_name')['damage_rate'].mean().sort_values(ascending=False).head(10)
print(top_damaged_products)
plt.figure(figsize=(10,6))
sns.barplot(x=top_damaged_products.values, y=top_damaged_products.index, palette=blinkit_palette_10,edgecolor='black')

plt.title('Top 10 Products with Highest Average Damage Rate')
plt.xlabel('Average Damage Rate')
plt.ylabel('Product Name')
plt.grid(True, axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Products with Highest Damage Rate
# product_name
# Wheat Flour          0.108939
# Toilet Cleaner       0.104519
# Frozen Vegetables    0.099343
# Butter               0.097963
# Lotion               0.097917
# Onions               0.097296
# Mango Drink          0.096361
# Chocolates           0.094872
# Pulses               0.094428
# Orange Juice         0.093688
# Name: damage_rate, dtype: float64
# /tmp/ipython-input-329-4065152399.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_damaged_products.values, y=top_damaged_products.index, palette=blinkit_palette_10,edgecolor='black')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

filtered_df = merged_df[merged_df['price'] < 1000]

plt.figure(figsize=(12, 6))
sns.boxplot(
 x='category',
    y='price',
    data=filtered_df,
    palette=blinkit_palette_10,
    showfliers=True,
    linewidth=1.2
)

plt.title('Price Distribution by Product Category', fontsize=14, weight='bold')
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Price (₹)', fontsize=12)
plt.xticks(rotation=45, ha='right')  # for readability
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-315-680763872.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /tmp/ipython-input-315-680763872.py:7: UserWarning:
# The palette list has fewer values (10) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(

# %%
import matplotlib.pyplot as plt

top_categories = df['category'].value_counts().nlargest(5).index
cat_stats = merged_df.groupby('category').agg({
    'order_id': 'count',
    'order_total': 'sum',
    'rating': 'mean'
}).loc[top_categories]

plt.figure(figsize=(10, 6))
plt.bar(cat_stats.index, cat_stats['order_id'], color="#FFD700", label='Orders')
plt.plot(cat_stats.index, cat_stats['order_total'] / 1000, color="#7AC142", marker='o', label='Revenue (K)')
plt.plot(cat_stats.index, cat_stats['rating'] * 1000, color="#000000", marker='x', label='Avg Rating x1000')
plt.title("Orders, Revenue & Avg Rating by Category")
plt.legend()
plt.ylabel("Count / Rating / Revenue")
plt.tight_layout()
plt.show()
